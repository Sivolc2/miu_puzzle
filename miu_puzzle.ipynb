# %% [markdown]
# # MIU Puzzle

# %% [markdown]
# MIU: alphabet
#
# 1. I > IU
# 2. Mx > Mxx
# 3. III > U
# 4. UU > del
#
# Show MI > MU ?
#
# MI > MIU >
# Or
# MI > MII > MIIII > MUI > MUIU > MUIUUIU > MUIIU > 2, 4 > MUIIIIU > MUUIU > MIU
#
#
#
# Set of transformations
#
# [Code iteration NN? Variation around mean, iterate and map? Reward novelty?]
#
# Human mind: iterate. Build meta set of transformations, abstract further.

# %%
def r0(s):
    if s[-1] == 'I':
        return(s[:-1] + 'IU')
    else:
        return(False)

def r1(s):
    if (s[0] == 'M'):
        return(s + s[1:])
    else:
        return(False)

def r2(s, side=0):
    if 'III' in s:
        if side == 0:
            return('U'.join(s.split('III', 1)))
        if side == 1:
            return('U'.join(s.rsplit('III', 1)))
    else:
        return(False)

def r3(s, side=0):
    if 'UU' in s:
        if side == 0:
            return(''.join(s.split('UU', 1)))
        if side == 1:
            return(''.join(s.rsplit('UU', 1)))
    else:
        return(False)

# %%
s = 'MI'
r1(r0(s))
# Out:
# 'MIUIU'

# %%
s = 'MI'
r3(r2(r3(r1(r3(r1(r0(r2(r1(r1(s)), 0)))))), 0))
# Out:
# 'MIU'

# %%
## Mechanic for calling transoformations programatically

## Direct Tree: build list of arrays 
## Build set of transformations into an array, build every permutation of that array
## Function which interprets array into function calls

def number_to_call(s, n, func_list):
    print('Calling function', func_list[n])
    print('Producwa', func_list[n](s))
    if func_list[n](s) is False:
        print('Failed transformation')
        return(False)
    else:
        return(func_list[n](s))

# %%
number_to_call('MU', 0, func_list)
# Out:
# Calling function <function r0 at 0x7fcb2a7159d0>
# Producwa False
# Failed transformation
# False

# %%
def ordering_segment(s, ordering, func_list):
    path = []
    for n in ordering:
        print(n)
        path = path + [n]
        s = number_to_call(s, n, func_list)
        if not s:
            print('End of loop')
            return(path)

# %%
func_list = [r0, r1, r2, r3]

ordering = [0, 1, 2, 3]

s = 'MIU'
ordering_segment(s, ordering, func_list)
# Out:
# 0
# Calling function <function r0 at 0x7fcb2a7159d0>
# Producwa False
# Failed transformation
# End of loop
# [0]

# %%
import random

# %%
random.randint?
# Out:
# Signature: random.randint(a, b)
# Docstring:
# Return random integer in range [a, b], including both end points.
#
# File:      ~/anaconda3/envs/mlenv/lib/python3.9/random.py
# Type:      method

# %%
[random.randint(0, 4) for i in range(0, 1000, 1)]
# Out:
# [4,
#  4,
#  1,
#  4,
#  4,
#  1,
#  4,
#  4,
#  0,
#  0,
#  0,
#  2,
#  4,
#  2,
#  1,
#  2,
#  4,
#  2,
#  3,
#  2,
#  2,
#  1,
#  2,
#  3,
#  3,
#  4,
#  1,
#  4,
#  0,
#  4,
#  2,
#  2,
#  0,
#  0,
#  2,
#  4,
#  0,
#  0,
#  4,
#  3,
#  1,
#  3,
#  1,
#  3,
#  3,
#  0,
#  0,
#  0,
#  1,
#  1,
#  2,
#  3,
#  1,
#  2,
#  0,
#  2,
#  0,
#  3,
#  0,
#  2,
#  1,
#  0,
#  0,
#  4,
#  0,
#  3,
#  4,
#  0,
#  3,
#  0,
#  1,
#  3,
#  4,
#  2,
#  3,
#  2,
#  0,
#  3,
#  0,
#  3,
#  1,
#  3,
#  2,
#  1,
#  3,
#  0,
#  2,
#  1,
#  0,
#  3,
#  4,
#  0,
#  4,
#  3,
#  3,
#  3,
#  3,
#  1,
#  2,
#  3,
#  2,
#  0,
#  3,
#  1,
#  2,
#  1,
#  4,
#  0,
#  1,
#  2,
#  2,
#  3,
#  2,
#  0,
#  1,
#  1,
#  4,
#  3,
#  1,
#  1,
#  1,
#  0,
#  2,
#  0,
#  1,
#  0,
#  0,
#  0,
#  2,
#  0,
#  4,
#  3,
#  3,
#  3,
#  1,
#  0,
#  1,
#  0,
#  4,
#  1,
#  2,
#  3,
#  4,
#  1,
#  2,
#  4,
#  1,
#  4,
#  4,
#  2,
#  0,
#  1,
#  3,
#  4,
#  1,
#  0,
#  4,
#  1,
#  4,
#  0,
#  1,
#  2,
#  2,
#  3,
#  1,
#  3,
#  0,
#  1,
#  2,
#  2,
#  1,
#  1,
#  0,
#  2,
#  4,
#  0,
#  3,
#  3,
#  4,
#  1,
#  0,
#  1,
#  3,
#  3,
#  4,
#  2,
#  2,
#  1,
#  4,
#  3,
#  3,
#  2,
#  0,
#  4,
#  4,
#  0,
#  2,
#  0,
#  4,
#  4,
#  4,
#  2,
#  4,
#  1,
#  0,
#  2,
#  2,
#  1,
#  2,
#  3,
#  4,
#  4,
#  4,
#  3,
#  0,
#  3,
#  2,
#  3,
#  2,
#  1,
#  3,
#  4,
#  1,
#  2,
#  0,
#  0,
#  0,
#  2,
#  1,
#  4,
#  2,
#  1,
#  4,
#  1,
#  3,
#  3,
#  4,
#  2,
#  0,
#  3,
#  1,
#  3,
#  0,
#  1,
#  3,
#  0,
#  4,
#  3,
#  1,
#  1,
#  0,
#  2,
#  3,
#  1,
#  2,
#  1,
#  3,
#  2,
#  3,
#  2,
#  3,
#  4,
#  1,
#  0,
#  0,
#  4,
#  3,
#  0,
#  2,
#  3,
#  0,
#  3,
#  3,
#  0,
#  4,
#  1,
#  0,
#  0,
#  2,
#  0,
#  2,
#  4,
#  0,
#  3,
#  1,
#  2,
#  1,
#  4,
#  2,
#  4,
#  1,
#  0,
#  1,
#  3,
#  0,
#  3,
#  3,
#  0,
#  4,
#  3,
#  4,
#  1,
#  1,
#  0,
#  0,
#  4,
#  2,
#  3,
#  0,
#  4,
#  4,
#  2,
#  0,
#  3,
#  1,
#  2,
#  4,
#  1,
#  0,
#  0,
#  4,
#  1,
#  2,
#  3,
#  0,
#  0,
#  2,
#  2,
#  1,
#  0,
#  4,
#  3,
#  2,
#  0,
#  2,
#  1,
#  1,
#  1,
#  3,
#  4,
#  4,
#  0,
#  4,
#  1,
#  1,
#  4,
#  4,
#  1,
#  3,
#  4,
#  4,
#  3,
#  3,
#  2,
#  0,
#  0,
#  3,
#  1,
#  4,
#  0,
#  3,
#  2,
#  3,
#  2,
#  1,
#  1,
#  3,
#  0,
#  0,
#  3,
#  1,
#  2,
#  1,
#  1,
#  2,
#  0,
#  2,
#  4,
#  3,
#  1,
#  1,
#  4,
#  4,
#  4,
#  0,
#  1,
#  4,
#  3,
#  2,
#  4,
#  1,
#  3,
#  0,
#  4,
#  0,
#  3,
#  4,
#  4,
#  1,
#  3,
#  2,
#  0,
#  1,
#  2,
#  0,
#  0,
#  0,
#  0,
#  1,
#  3,
#  2,
#  4,
#  4,
#  0,
#  0,
#  0,
#  2,
#  0,
#  3,
#  0,
#  1,
#  1,
#  3,
#  2,
#  3,
#  2,
#  0,
#  1,
#  3,
#  3,
#  4,
#  0,
#  0,
#  2,
#  1,
#  1,
#  0,
#  1,
#  0,
#  1,
#  1,
#  0,
#  1,
#  3,
#  1,
#  4,
#  4,
#  0,
#  3,
#  3,
#  0,
#  1,
#  2,
#  1,
#  0,
#  3,
#  3,
#  0,
#  3,
#  0,
#  2,
#  0,
#  0,
#  1,
#  4,
#  0,
#  4,
#  0,
#  4,
#  3,
#  2,
#  4,
#  2,
#  3,
#  1,
#  4,
#  4,
#  3,
#  2,
#  0,
#  1,
#  2,
#  1,
#  4,
#  0,
#  0,
#  4,
#  1,
#  1,
#  3,
#  0,
#  1,
#  0,
#  3,
#  2,
#  1,
#  2,
#  0,
#  1,
#  3,
#  1,
#  4,
#  4,
#  0,
#  1,
#  4,
#  2,
#  4,
#  1,
#  3,
#  4,
#  2,
#  1,
#  3,
#  2,
#  2,
#  0,
#  0,
#  3,
#  1,
#  4,
#  2,
#  4,
#  2,
#  2,
#  1,
#  2,
#  4,
#  4,
#  0,
#  2,
#  1,
#  2,
#  0,
#  3,
#  2,
#  2,
#  3,
#  3,
#  3,
#  1,
#  3,
#  0,
#  0,
#  3,
#  3,
#  1,
#  4,
#  2,
#  3,
#  2,
#  4,
#  4,
#  3,
#  3,
#  2,
#  2,
#  1,
#  1,
#  0,
#  2,
#  4,
#  2,
#  3,
#  3,
#  4,
#  3,
#  1,
#  1,
#  3,
#  2,
#  1,
#  3,
#  2,
#  1,
#  4,
#  2,
#  0,
#  3,
#  2,
#  3,
#  3,
#  4,
#  2,
#  4,
#  3,
#  2,
#  1,
#  3,
#  1,
#  4,
#  3,
#  1,
#  3,
#  2,
#  3,
#  3,
#  0,
#  2,
#  3,
#  0,
#  4,
#  2,
#  2,
#  2,
#  2,
#  1,
#  3,
#  4,
#  3,
#  3,
#  4,
#  0,
#  0,
#  2,
#  1,
#  0,
#  0,
#  0,
#  0,
#  1,
#  0,
#  3,
#  1,
#  2,
#  0,
#  3,
#  2,
#  0,
#  0,
#  4,
#  1,
#  3,
#  4,
#  3,
#  4,
#  0,
#  3,
#  4,
#  1,
#  1,
#  2,
#  0,
#  1,
#  3,
#  0,
#  4,
#  4,
#  3,
#  3,
#  3,
#  4,
#  0,
#  3,
#  2,
#  2,
#  2,
#  0,
#  3,
#  1,
#  0,
#  2,
#  4,
#  2,
#  2,
#  3,
#  1,
#  2,
#  3,
#  3,
#  3,
#  4,
#  0,
#  4,
#  3,
#  1,
#  0,
#  3,
#  2,
#  1,
#  2,
#  0,
#  4,
#  2,
#  2,
#  1,
#  3,
#  3,
#  1,
#  0,
#  1,
#  4,
#  3,
#  3,
#  0,
#  2,
#  1,
#  2,
#  0,
#  1,
#  1,
#  3,
#  3,
#  1,
#  2,
#  1,
#  0,
#  0,
#  3,
#  3,
#  2,
#  2,
#  3,
#  0,
#  2,
#  1,
#  3,
#  3,
#  4,
#  2,
#  2,
#  4,
#  1,
#  3,
#  4,
#  3,
#  3,
#  2,
#  1,
#  4,
#  3,
#  0,
#  3,
#  0,
#  1,
#  4,
#  4,
#  3,
#  2,
#  4,
#  0,
#  1,
#  2,
#  1,
#  2,
#  0,
#  3,
#  3,
#  2,
#  4,
#  2,
#  0,
#  1,
#  3,
#  1,
#  3,
#  1,
#  4,
#  2,
#  3,
#  2,
#  4,
#  1,
#  0,
#  1,
#  1,
#  3,
#  1,
#  2,
#  3,
#  2,
#  2,
#  1,
#  1,
#  2,
#  2,
#  1,
#  1,
#  3,
#  4,
#  0,
#  2,
#  3,
#  3,
#  0,
#  0,
#  3,
#  2,
#  1,
#  2,
#  2,
#  4,
#  0,
#  1,
#  1,
#  0,
#  1,
#  0,
#  2,
#  3,
#  4,
#  2,
#  2,
#  2,
#  2,
#  4,
#  1,
#  2,
#  0,
#  2,
#  2,
#  0,
#  0,
#  3,
#  1,
#  2,
#  1,
#  0,
#  3,
#  0,
#  3,
#  1,
#  3,
#  0,
#  0,
#  3,
#  0,
#  0,
#  4,
#  0,
#  2,
#  4,
#  3,
#  4,
#  2,
#  3,
#  1,
#  2,
#  4,
#  1,
#  2,
#  4,
#  1,
#  1,
#  0,
#  3,
#  4,
#  3,
#  4,
#  2,
#  0,
#  3,
#  4,
#  1,
#  2,
#  3,
#  2,
#  1,
#  1,
#  3,
#  3,
#  4,
#  1,
#  2,
#  1,
#  4,
#  1,
#  4,
#  2,
#  1,
#  3,
#  2,
#  0,
#  3,
#  4,
#  0,
#  3,
#  4,
#  3,
#  4,
#  1,
#  0,
#  4,
#  0,
#  0,
#  3,
#  4,
#  2,
#  2,
#  1,
#  3,
#  0,
#  0,
#  2,
#  3,
#  1,
#  2,
#  3,
#  4,
#  3,
#  1,
#  2,
#  3,
#  2,
#  1,
#  2,
#  4,
#  1,
#  1,
#  1,
#  1,
#  1,
#  0,
#  2,
#  2,
#  1,
#  4,
#  1,
#  3,
#  3,
#  2,
#  0,
#  1,
#  1,
#  3,
#  4,
#  2,
#  2,
#  4,
#  2,
#  0,
#  0,
#  1,
#  1,
#  0,
#  4,
#  3,
#  4,
#  4,
#  1,
#  3,
#  3,
#  1,
#  4,
#  0,
#  1,
#  2,
#  1,
#  3,
#  2,
#  3,
#  1,
#  3,
#  1,
#  1,
#  1,
#  3,
#  4,
#  1,
#  0,
#  0,
#  3,
#  3,
#  2,
#  2,
#  1,
#  1,
#  1,
#  2,
#  4,
#  0,
#  2,
#  2,
#  4,
#  0,
#  3,
#  2,
#  2,
#  0,
#  0,
#  1,
#  0,
#  1,
#  0,
#  2,
#  3,
#  4,
#  4,
#  0,
#  3,
#  2,
#  1,
#  2,
#  3,
#  4,
#  3,
#  0,
#  4,
#  2,
#  2]

# %%
## Systematic tree ordering:: iterate forward after invalid rule.
## Select trees based on size

# %%
## Systematic way to solve: symbolic form for every transformation. Matrix solution?
